# %% [markdown]
# <a href="https://colab.research.google.com/github/scysco/ONE-DATASCIENCE/blob/main/05_Pandas_IO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CSV Files**

# %%
import pandas as pd

# %% [markdown]
# ## **Importing CSV**

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html

# %%
data = pd.read_csv('/content/drive/MyDrive/ONE/05_Pandas_IO/superstore_data.csv') # Saved as dataframe
data.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %% [markdown]
# **File separated by semicolon**

# %%
data_semicolon = pd.read_csv('/content/drive/MyDrive/ONE/05_Pandas_IO/superstore_data_punto_coma.csv', sep=';')
data_semicolon.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %% [markdown]
# ## **Exploring parameters**

# %%
data_firstlines =  pd.read_csv('/content/drive/MyDrive/ONE/05_Pandas_IO/superstore_data.csv', nrows=5) # working with the first 5 lines
data_firstlines
# Out:
#       Id  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced   84835        0         0
# 1      1        1961  Graduation         Single   57091        0         0
# 2  10476        1958  Graduation        Married   67267        0         1
# 3   1386        1967  Graduation       Together   32474        1         1
# 4   5371        1989  Graduation         Single   21474        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# ...

# %%
# Restricting columns, also works with their position number [0,1,4]
data_selection =  pd.read_csv('/content/drive/MyDrive/ONE/05_Pandas_IO/superstore_data.csv', usecols = ['Id', 'Year_Birth', 'Income'])
data_selection
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %% [markdown]
# ## **Exporting CSV**

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html

# %% [markdown]
# **With the index "Error"**

# %%
data_selection.to_csv('/content/drive/MyDrive/ONE/05_Pandas_IO/clientes_mercado(w_index).csv')

# %%
clientes_mercado_wi = pd.read_csv('/content/drive/MyDrive/ONE/05_Pandas_IO/clientes_mercado(w_index).csv')
clientes_mercado_wi
# Out:
#       Unnamed: 0     Id  Year_Birth   Income
# 0              0   1826        1970  84835.0
# 1              1      1        1961  57091.0
# 2              2  10476        1958  67267.0
# 3              3   1386        1967  32474.0
# 4              4   5371        1989  21474.0
# ...          ...    ...         ...      ...
# 2235        2235  10142        1976  66476.0
# 2236        2236   5263        1977  31056.0
# 2237        2237     22        1976  46310.0
# 2238        2238    528        1978  65819.0
# 2239        2239   4070        1969  94871.0
#
# [2240 rows x 4 columns]

# %% [markdown]
# **Without the index "error"**

# %%
data_selection.to_csv('/content/drive/MyDrive/ONE/05_Pandas_IO/clientes_mercado.csv', index=False)

# %%
clientes_mercado = pd.read_csv('/content/drive/MyDrive/ONE/05_Pandas_IO/clientes_mercado.csv')
clientes_mercado
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %% [markdown]
# ## **Desafío: leyendo datos con múltiples parámetros**

# %% [markdown]
# Disponemos de un archivo en formato CSV, el cual se obtuvo de la página Información de Salud (TABNET) - DATASUS. Este archivo contiene los gastos hospitalarios públicos de cada una de las Unidades de la Federación Brasileña desde enero de 2008 hasta marzo de 2021.
#
# Se debe leer este archivo usando la función read_csv de la biblioteca Pandas. Se deben agregar algunos parámetros para que la lectura se realice correctamente. Entonces, aquí hay algunos consejos:
#
# 1. Asegúrese de que el archivo CSV esté separado por una coma o punto y coma.
# 2. La codificación del archivo es ISO-8859-1.
# 3. Las primeras tres líneas del archivo se pueden ignorar, ya que el encabezado sólo comienza en la cuarta línea.
# 4. Las últimas 9 líneas también se pueden ignorar, ya que son sólo información sobre dónde se tomaron los datos.
# 5. Para eliminar las últimas líneas es necesario agregar el parámetro engine='python'.

# %%
import pandas as pd

## separator = ;
## I should consider ISO-8859-1 encoding  - encoding='ISO-8859-1'
## I have to skip the first 3 lines - skyprows=3
## I must skip the last 9 lines - skipfooter=9
## Finally, I must follow the indication of engine='python

data_sus = pd.read_csv('/content/drive/MyDrive/ONE/05_Pandas_IO/datos_sus.csv', encoding='ISO-8859-1', sep=';', skiprows=3, skipfooter = 9, engine='python')
data_sus.head()
# Out:
#   Unidade da Federação     2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# 0             Rondônia   1388528,39   2931283,42   1541682,52   1525314,96
# 1                 Acre    902416,00   1497206,26   1794028,48   1730469,42
# 2             Amazonas   4735529,42   7118990,57   8196635,49   8259378,42
# 3              Roraima    657889,53    777939,31    718688,03    839994,39
# 4                 Pará  18864744,11  19553758,20  21937342,70  20842829,69
#
#       2008/Mai     2008/Jun     2008/Jul     2008/Ago     2008/Set  ...  \
# 0   1645953,84   1406150,68   3065279,01   3231494,61   3117178,63  ...
# 1   1819443,92   1828496,00   2511754,59   2089107,14   2275708,53  ...
# 2   7831399,90   8477273,62   9368858,72   9352532,70   9363099,35  ...
# 3    862347,96    832440,66    996693,09    894271,18    910424,17  ...
# 4  23249952,88  23240687,56  24002223,56  23341218,03  25172261,32  ...
#
#       2020/Jul     2020/Ago     2020/Set     2020/Out     2020/Nov  \
# ...

# %% [markdown]
# # **Excel Files**

# %%
import pandas as pd

# %% [markdown]
# ## **Importing excel**

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html

# %%
url = '/content/drive/MyDrive/ONE/05_Pandas_IO/emisiones_CO2.xlsx'

data_co2 = pd.read_excel(url)
data_co2
# Out:
#              País ISO 3166-1 alpha-3   Año         Total        Carbón  \
# 0      Afganistán                AFG  1750  0.000000e+00           NaN
# 1      Afganistán                AFG  1751  0.000000e+00           NaN
# 2      Afganistán                AFG  1752  0.000000e+00           NaN
# 3      Afganistán                AFG  1753  0.000000e+00           NaN
# 4      Afganistán                AFG  1754  0.000000e+00           NaN
# ...           ...                ...   ...           ...           ...
# 63099      Global                WLD  2017  3.609674e+10  1.450697e+10
# 63100      Global                WLD  2018  3.682651e+10  1.474683e+10
# 63101      Global                WLD  2019  3.708256e+10  1.472598e+10
# 63102      Global                WLD  2020  3.526409e+10  1.417456e+10
# 63103      Global                WLD  2021  3.712385e+10  1.497960e+10
#
#              Aceite           Gas       Cemento        Quema        Otros  \
# ...

# %% [markdown]
# ## **Exploring parameters**

# %% [markdown]
# **Finding sheet Names**

# %%
pd.ExcelFile(url).sheet_names
# Out:
# ['emisiones_C02', 'emisiones_percapita', 'fuentes']

# %% [markdown]
# **Opening a specific Excel sheet**

# %%
percapita = pd.read_excel(url, sheet_name='emisiones_percapita')
percapita.tail()
# Out:
#          País ISO 3166-1 alpha-3   Año      Total     Carbón     Aceite  \
# 63099  Global                WLD  2017  4749682.0  1908857.0  1610910.0
# 63100  Global                WLD  2018  4792753.0  1919213.0  1596350.0
# 63101  Global                WLD  2019  4775633.0  1896468.0  1589920.0
# 63102  Global                WLD  2020  4497423.0  1807760.0  1427353.0
# 63103  Global                WLD  2021  4693699.0  1893923.0  1496614.0
#
#              Gas   Cemento    Quema    Otros
# 63099   940144.0  198416.0  51579.0  39776.0
# 63100   979965.0  204225.0  53634.0  39366.0
# 63101   984878.0  208309.0  56569.0  39490.0
# 63102   963695.0  208844.0  51981.0  37789.0
# 63103  1001585.0  211472.0  52663.0  37443.0

# %%
fuentes = pd.read_excel(url, sheet_name='fuentes')
fuentes.sample(5)
# Out:
#                                  País ISO 3166-1 alpha-3   Año   Total  \
# 59064          Emiratos Árabes Unidos                ARE  1790  [NONE]
# 25038                        Islandia                ISL  1764  [NONE]
# 5062                      Bielorrusia                BLR  1916  [NONE]
# 13363                         Curazao                CUW  1785  [NONE]
# 48432  Feel Marthes (Parte Holandesa)                SXM  1766  [NONE]
#
#        Carbón  Aceite     Gas        Cemento   Quema   Otros Per Capita
# 59064  [NONE]  [NONE]  [NONE]         [NONE]  [NONE]  [NONE]     [NONE]
# 25038  [NONE]  [NONE]  [NONE]  Andrew cement  [NONE]  [NONE]     [NONE]
# 5062   [NONE]  [NONE]  [NONE]         [NONE]  [NONE]  [NONE]     [NONE]
# 13363  [NONE]  [NONE]  [NONE]         [NONE]  [NONE]  [NONE]     [NONE]
# 48432  [NONE]  [NONE]  [NONE]         [NONE]  [NONE]  [NONE]     [NONE]

# %% [markdown]
# **usecols**

# %%
intervalo = pd.read_excel(url, sheet_name='emisiones_C02', usecols='A:D')
intervalo
# Out:
#              País ISO 3166-1 alpha-3   Año         Total
# 0      Afganistán                AFG  1750  0.000000e+00
# 1      Afganistán                AFG  1751  0.000000e+00
# 2      Afganistán                AFG  1752  0.000000e+00
# 3      Afganistán                AFG  1753  0.000000e+00
# 4      Afganistán                AFG  1754  0.000000e+00
# ...           ...                ...   ...           ...
# 63099      Global                WLD  2017  3.609674e+10
# 63100      Global                WLD  2018  3.682651e+10
# 63101      Global                WLD  2019  3.708256e+10
# 63102      Global                WLD  2020  3.526409e+10
# 63103      Global                WLD  2021  3.712385e+10
#
# [63104 rows x 4 columns]

# %% [markdown]
# **nrows**

# %%
intervalo = pd.read_excel(url, sheet_name='emisiones_C02', usecols='A:D', nrows = 10)
intervalo
# Out:
#          País ISO 3166-1 alpha-3   Año  Total
# 0  Afganistán                AFG  1750      0
# 1  Afganistán                AFG  1751      0
# 2  Afganistán                AFG  1752      0
# 3  Afganistán                AFG  1753      0
# 4  Afganistán                AFG  1754      0
# 5  Afganistán                AFG  1755      0
# 6  Afganistán                AFG  1756      0
# 7  Afganistán                AFG  1757      0
# 8  Afganistán                AFG  1758      0
# 9  Afganistán                AFG  1759      0

# %% [markdown]
# ## **Exporting Excel**

# %%
intervalo.to_excel('/content/drive/MyDrive/ONE/05_Pandas_IO/co4_percapita.xlsx', index=False)

# %%
pd.read_excel('/content/drive/MyDrive/ONE/05_Pandas_IO/co4_percapita.xlsx')
# Out:
#          País ISO 3166-1 alpha-3   Año  Total
# 0  Afganistán                AFG  1750      0
# 1  Afganistán                AFG  1751      0
# 2  Afganistán                AFG  1752      0
# 3  Afganistán                AFG  1753      0
# 4  Afganistán                AFG  1754      0
# 5  Afganistán                AFG  1755      0
# 6  Afganistán                AFG  1756      0
# 7  Afganistán                AFG  1757      0
# 8  Afganistán                AFG  1758      0
# 9  Afganistán                AFG  1759      0

# %% [markdown]
# ## **Working with Google sheets**

# %% [markdown]
# link: https://docs.google.com/spreadsheets/d/1bFjiFD-s7v5w9YQs2NwlcKQBvh9bxjCP/edit?usp=sharing&ouid=116132143742426642244&rtpof=true&sd=true

# %%
sheet_id = '1bFjiFD-s7v5w9YQs2NwlcKQBvh9bxjCP'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'

data_co2_sheets = pd.read_csv(url)
data_co2_sheets
# Out:
#              País ISO 3166-1 alpha-3   Año           Total          Carbón  \
# 0      Afganistán                AFG  1750               0             NaN
# 1      Afganistán                AFG  1751               0             NaN
# 2      Afganistán                AFG  1752               0             NaN
# 3      Afganistán                AFG  1753               0             NaN
# 4      Afganistán                AFG  1754               0             NaN
# ...           ...                ...   ...             ...             ...
# 63099      Global                WLD  2017  36,096,739,276  14,506,973,805
# 63100      Global                WLD  2018  36,826,506,600  14,746,830,688
# 63101      Global                WLD  2019  37,082,558,969  14,725,978,025
# 63102      Global                WLD  2020  35,264,085,734  14,174,564,010
# 63103      Global                WLD  2021  37,123,850,352  14,979,598,083
#
# ...

# %% [markdown]
# **With sheet name**

# %%
sheet_id = '1bFjiFD-s7v5w9YQs2NwlcKQBvh9bxjCP'
sheet_name = 'emisiones_percapita'
url_percapita = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

percapita_sheets = pd.read_csv(url_percapita)
percapita_sheets
# Out:
#              País ISO 3166-1 alpha-3   Año      Total     Carbón     Aceite  \
# 0      Afganistán                AFG  1750        NaN        NaN        NaN
# 1      Afganistán                AFG  1751        NaN        NaN        NaN
# 2      Afganistán                AFG  1752        NaN        NaN        NaN
# 3      Afganistán                AFG  1753        NaN        NaN        NaN
# 4      Afganistán                AFG  1754        NaN        NaN        NaN
# ...           ...                ...   ...        ...        ...        ...
# 63099      Global                WLD  2017  4,749,682  1,908,857  1,610,910
# 63100      Global                WLD  2018  4,792,753  1,919,213  1,596,350
# 63101      Global                WLD  2019  4,775,633  1,896,468  1,589,920
# 63102      Global                WLD  2020  4,497,423  1,807,760  1,427,353
# 63103      Global                WLD  2021  4,693,699  1,893,923  1,496,614
#
#              Gas  Cemento   Quema   Otros
# ...

# %% [markdown]
# ## **Desafío: leyendo datos de otro link**

# %% [markdown]
# Tenemos un [link](https://docs.google.com/spreadsheets/d/1bFjiFD-s7v5w9YQs2NwlcKQBvh9bxjCP/edit?gid=801830750#gid=801830750) de Google Sheets que contiene datos importantes sobre las emisiones de dióxido de carbono en todo el mundo. El conjunto de datos se obtuvo de Kaggle y consta de las emisiones de CO2 per cápita de todos los países del mundo entre 1990 y 2019.
#
# En este desafío, tu función es leer este link de Google Sheets y luego guardar el DataFrame obtenido en formato CSV.

# %%
sheet_id = '1bFjiFD-s7v5w9YQs2NwlcKQBvh9bxjCP'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'

data = pd.read_csv(url)
data
# Out:
#              País ISO 3166-1 alpha-3   Año           Total          Carbón  \
# 0      Afganistán                AFG  1750               0             NaN
# 1      Afganistán                AFG  1751               0             NaN
# 2      Afganistán                AFG  1752               0             NaN
# 3      Afganistán                AFG  1753               0             NaN
# 4      Afganistán                AFG  1754               0             NaN
# ...           ...                ...   ...             ...             ...
# 63099      Global                WLD  2017  36,096,739,276  14,506,973,805
# 63100      Global                WLD  2018  36,826,506,600  14,746,830,688
# 63101      Global                WLD  2019  37,082,558,969  14,725,978,025
# 63102      Global                WLD  2020  35,264,085,734  14,174,564,010
# 63103      Global                WLD  2021  37,123,850,352  14,979,598,083
#
# ...

# %%
data.to_csv('/content/drive/MyDrive/ONE/05_Pandas_IO/desafio02.csv', index=False)
pd.read_csv('/content/drive/MyDrive/ONE/05_Pandas_IO/desafio02.csv')
# Out:
#              País ISO 3166-1 alpha-3   Año           Total          Carbón  \
# 0      Afganistán                AFG  1750               0             NaN
# 1      Afganistán                AFG  1751               0             NaN
# 2      Afganistán                AFG  1752               0             NaN
# 3      Afganistán                AFG  1753               0             NaN
# 4      Afganistán                AFG  1754               0             NaN
# ...           ...                ...   ...             ...             ...
# 63099      Global                WLD  2017  36,096,739,276  14,506,973,805
# 63100      Global                WLD  2018  36,826,506,600  14,746,830,688
# 63101      Global                WLD  2019  37,082,558,969  14,725,978,025
# 63102      Global                WLD  2020  35,264,085,734  14,174,564,010
# 63103      Global                WLD  2021  37,123,850,352  14,979,598,083
#
# ...

# %% [markdown]
# # **JSON Files**

# %%
import pandas as pd

# %% [markdown]
# ## **Importing JSON**

# %%
url = '/content/drive/MyDrive/ONE/05_Pandas_IO/pacientes.json'
data_pacientes = pd.read_json(url)
data_pacientes
# Out:
#      ID_paciente Enfermedad_corazon    IMC Fumador Consumo_alcohol AVC  \
# 0              0                 No  16.60      Sí              No  No
# 1              1                 No  20.34      No              No  Sí
# 2              2                 No  26.58      Sí              No  No
# 3              3                 No  24.21      No              No  No
# 4              4                 No  23.71      No              No  No
# ..           ...                ...    ...     ...             ...  ..
# 995          995                 No  28.29      Sí              No  No
# 996          996                 No  25.69      Sí              No  No
# 997          997                 Sí  26.99      No              No  No
# 998          998                 No  44.29      No              No  No
# 999          999                 No  25.83      No              No  No
#
#      Salud_fisica  Salud_mental Dificultad_caminar Sexo_biologico Rango_edad  \
# ...

# %% [markdown]
# ## **Exploring parameters**

# %% [markdown]
# **Working with dictionaries**

# %%
url = '/content/drive/MyDrive/ONE/05_Pandas_IO/pacientes_2.json'
data_pacientes2 = pd.read_json(url)
data_pacientes2
# Out:
#                                  Investigación   Año  \
# 0  Indicadores clave de enfermedades cardíacas  2020
# 1  Indicadores clave de enfermedades cardíacas  2020
# 2  Indicadores clave de enfermedades cardíacas  2020
#
#                                            Pacientes
# 0  {'ID': '01', 'Rango_edad': '55-59', 'Sexo_biol...
# 1  {'ID': '02', 'Rango_edad': '80 ó +', 'Sexo_bio...
# 2  {'ID': '03', 'Rango_edad': '65-69', 'Sexo_biol...

# %%
normalized_df = pd.json_normalize(data_pacientes2['Pacientes'])
normalized_df
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0  01      55-59          Mujer  Blanca  16.60      Sí              No
# 1  02     80 ó +          Mujer  Blanca  20.34      No              No
# 2  03      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]

# %% [markdown]
# ## **Exporting JSON**

# %%
normalized_df.to_json('/content/drive/MyDrive/ONE/05_Pandas_IO/historico_pacientes_normalizado.json')
pd.read_json('/content/drive/MyDrive/ONE/05_Pandas_IO/historico_pacientes_normalizado.json')
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0   1      55-59          Mujer  Blanca  16.60      Sí              No
# 1   2     80 ó +          Mujer  Blanca  20.34      No              No
# 2   3      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]

# %% [markdown]
# ## **Desafío: normalizar el JSON obtenido de una API**

# %% [markdown]
# ### **Importing from API**

# %%
import requests
import json

datos_frutas = requests.get('https://fruityvice.com/api/fruit/all')

resultado = json.loads(datos_frutas.text)

pd.DataFrame(resultado).head() ## just for viewing
# Out:
#          name  id      family         order      genus  \
# 0   Persimmon  52   Ebenaceae       Rosales  Diospyros
# 1  Strawberry   3    Rosaceae       Rosales   Fragaria
# 2      Banana   1    Musaceae  Zingiberales       Musa
# 3      Tomato   5  Solanaceae     Solanales    Solanum
# 4        Pear   4    Rosaceae       Rosales      Pyrus
#
#                                           nutritions
# 0  {'calories': 81, 'fat': 0.0, 'sugar': 18.0, 'c...
# 1  {'calories': 29, 'fat': 0.4, 'sugar': 5.4, 'ca...
# 2  {'calories': 96, 'fat': 0.2, 'sugar': 17.2, 'c...
# 3  {'calories': 74, 'fat': 0.2, 'sugar': 2.6, 'ca...
# 4  {'calories': 57, 'fat': 0.1, 'sugar': 10.0, 'c...

# %% [markdown]
# ### **Challenge**

# %% [markdown]
# Este DataFrame tiene 6 columnas: genus (género), name (nombre), id, family (familia), order (orden) e nutritions (nutriciones). Observe que la columna nutritions tiene toda la información nutricional anidada en ella. Por tanto, es necesario normalizar los datos.
#
# El desafío ahora es normalizar este DataFrame.

# %%
df_frutas_normalizado = pd.json_normalize(resultado)
df_frutas_normalizado.head()
# Out:
#          name  id      family         order      genus  nutritions.calories  \
# 0   Persimmon  52   Ebenaceae       Rosales  Diospyros                   81
# 1  Strawberry   3    Rosaceae       Rosales   Fragaria                   29
# 2      Banana   1    Musaceae  Zingiberales       Musa                   96
# 3      Tomato   5  Solanaceae     Solanales    Solanum                   74
# 4        Pear   4    Rosaceae       Rosales      Pyrus                   57
#
#    nutritions.fat  nutritions.sugar  nutritions.carbohydrates  \
# 0             0.0              18.0                      18.0
# 1             0.4               5.4                       5.5
# 2             0.2              17.2                      22.0
# 3             0.2               2.6                       3.9
# 4             0.1              10.0                      15.0
#
#    nutritions.protein
# 0                 0.0
# 1                 0.8
# 2                 1.0
# 3                 0.9
# ...

# %% [markdown]
# # **HTML & XML Files**

# %%
import pandas as pd

# %% [markdown]
# ## **Importing HTML**

# %%
data_html = pd.read_html('/content/drive/MyDrive/ONE/05_Pandas_IO/peliculas_wikipedia.html')
data_html
# Out:
# [       0                      1
#  0   1998             100 Movies
#  1   1999              100 Stars
#  2   2000             100 Laughs
#  3   2001            100 Thrills
#  4   2002           100 Passions
#  5   2003  100 Heroes & Villains
#  6   2004              100 Songs
#  7   2005       100 Movie Quotes
#  8   2005              25 Scores
#  9   2006             100 Cheers
#  10  2006            25 Musicals
#  11  2007   100 Movies (Updated)
#  12  2008        AFI's 10 Top 10
#  13   vte                    vte,
#                              Film  Release year              Director  \
#  0                   Citizen Kane          1941          Orson Welles
#  1                     Casablanca          1942        Michael Curtiz
#  2                  The Godfather          1972  Francis Ford Coppola
#  3             Gone with the Wind          1939        Victor Fleming
#  4             Lawrence of Arabia          1962            David Lean
# ...

# %% [markdown]
# ## **Cleaning the html**

# %%
type(data_html)
# Out:
# list

# %%
len(data_html)
# Out:
# 3

# %%
peliculas_df = data_html[1]
peliculas_df
# Out:
#                             Film  Release year              Director  \
# 0                   Citizen Kane          1941          Orson Welles
# 1                     Casablanca          1942        Michael Curtiz
# 2                  The Godfather          1972  Francis Ford Coppola
# 3             Gone with the Wind          1939        Victor Fleming
# 4             Lawrence of Arabia          1962            David Lean
# ..                           ...           ...                   ...
# 95                 The Searchers          1956             John Ford
# 96              Bringing Up Baby          1938          Howard Hawks
# 97                    Unforgiven          1992        Clint Eastwood
# 98  Guess Who's Coming to Dinner          1967        Stanley Kramer
# 99           Yankee Doodle Dandy          1942        Michael Curtiz
#
#                       Production companies  Rank
# 0                       RKO Radio Pictures     1
# ...

# %% [markdown]
# ## **Exporting HTML**

# %%
peliculas_df.to_html('/content/drive/MyDrive/ONE/05_Pandas_IO/peliculas.html', index=False)
pd.read_html('/content/drive/MyDrive/ONE/05_Pandas_IO/peliculas.html')
# Out:
# [                            Film  Release year              Director  \
#  0                   Citizen Kane          1941          Orson Welles
#  1                     Casablanca          1942        Michael Curtiz
#  2                  The Godfather          1972  Francis Ford Coppola
#  3             Gone with the Wind          1939        Victor Fleming
#  4             Lawrence of Arabia          1962            David Lean
#  ..                           ...           ...                   ...
#  95                 The Searchers          1956             John Ford
#  96              Bringing Up Baby          1938          Howard Hawks
#  97                    Unforgiven          1992        Clint Eastwood
#  98  Guess Who's Coming to Dinner          1967        Stanley Kramer
#  99           Yankee Doodle Dandy          1942        Michael Curtiz
#
#                        Production companies  Rank
#  0                       RKO Radio Pictures     1
# ...

# %%
peliculas_df.to_csv('/content/drive/MyDrive/ONE/05_Pandas_IO/peliculas.csv', index=False)
pd.read_csv('/content/drive/MyDrive/ONE/05_Pandas_IO/peliculas.csv')
# Out:
#                             Film  Release year              Director  \
# 0                   Citizen Kane          1941          Orson Welles
# 1                     Casablanca          1942        Michael Curtiz
# 2                  The Godfather          1972  Francis Ford Coppola
# 3             Gone with the Wind          1939        Victor Fleming
# 4             Lawrence of Arabia          1962            David Lean
# ..                           ...           ...                   ...
# 95                 The Searchers          1956             John Ford
# 96              Bringing Up Baby          1938          Howard Hawks
# 97                    Unforgiven          1992        Clint Eastwood
# 98  Guess Who's Coming to Dinner          1967        Stanley Kramer
# 99           Yankee Doodle Dandy          1942        Michael Curtiz
#
#                       Production companies  Rank
# 0                       RKO Radio Pictures     1
# ...

# %% [markdown]
# ## **Importing XML**

# %%
data_xml = pd.read_xml('/content/drive/MyDrive/ONE/05_Pandas_IO/imdb_top_1000.xml')
data_xml
# Out:
#      index                                        Poster_Link  \
# 0        0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1        1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2        2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3        3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4        4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..     ...                                                ...
# 995    995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996    996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997    997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998    998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999    999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# ...

# %% [markdown]
# ## **Exporting XML**

# %%
data_xml.to_xml('/content/drive/MyDrive/ONE/05_Pandas_IO/peliculas_imdb.xml')
pd.read_xml('/content/drive/MyDrive/ONE/05_Pandas_IO/peliculas_imdb.xml')
# Out:
#      level_0  index                                        Poster_Link  \
# 0          0      0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1          1      1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2          2      2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3          3      3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4          4      4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..       ...    ...                                                ...
# 995      995    995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996      996    996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997      997    997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998      998    998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999      999    999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# ...

# %% [markdown]
# ## **Desafío: leer una tabla de una página web**

# %% [markdown]
# Vanessa es una científica de datos que está haciendo algunos análisis con datos ambientales. Está desarrollando un proyecto para evaluar el impacto ambiental de las actividades humanas en diferentes países del mundo, pero para ello necesita estimaciones de población de esos países. Al buscar en Internet, encontró una tabla de estimaciones de población en un artículo de la página de [Wikipedia](https://es.wikipedia.org/wiki/Anexo:Pa%C3%ADses_y_territorios_dependientes_por_poblaci%C3%B3n).
#
# Al igual que Vanessa, tu desafío es obtener un DataFrame de la tabla que contiene la información del número de habitantes de cada país.

# %%
import pandas as pd

data_poblacion = pd.read_html('https://es.wikipedia.org/wiki/Anexo:Pa%C3%ADses_y_territorios_dependientes_por_poblaci%C3%B3n')
data_poblacion[0]
# Out:
#      N.º                   País (o territorio dependiente)  \
# 0      1                                             India
# 1      2                                        China[12]​
# 2      3                                    Estados Unidos
# 3      4                                         Indonesia
# 4      5                                          Pakistán
# ..   ...                                               ...
# 241  242                           Islas Cocos (Australia)
# 242  243  Islas Ultramarinas Menores de los Estados Unidos
# 243  244                               Islas Pitcairn (RU)
# 244  NaN                                             Mundo
# 245   N°                   País (o territorio dependiente)
#
#     Proyección exponencial de la población al 1/7/2025[7]​  \
# 0                                        1 417 492 000
# 1                                        1 407 934 000
# 2                                          342 181 000
# ...

# %% [markdown]
# # **SQL**

# %% [markdown]
# ## **The libraries**

# %%
import sqlalchemy
from sqlalchemy import create_engine,MetaData, Table, inspect, text

# %% [markdown]
# ## **Running SQL locally**

# %%
engine = create_engine('sqlite:///:memory:')

# %% [markdown]
# ## **Reading the CSV**

# %%
import pandas as pd

url = '/content/drive/MyDrive/ONE/05_Pandas_IO/clientes_banco.csv'
data_clientes = pd.read_csv(url)
data_clientes
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008808    52  Nivel intermedio           Soltero               1
# 4          5008809    52  Nivel intermedio           Soltero               1
# ...            ...   ...               ...               ...             ...
# 438458     6840104    62  Nivel intermedio        Divorciado               1
# 438459     6840222    43  Nivel intermedio           Soltero               1
# 438460     6841878    22    Nivel superior           Soltero               1
# 438461     6842765    59  Nivel intermedio            Casado               2
# 438462     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %% [markdown]
# ## **Exporting to SQL**

# %%
data_clientes.to_sql('clientes', engine, index=False)
# Out:
# 438463

# %%
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['clientes', 'empleados']

# %% [markdown]
# ## **Queries**

# %%
query = 'SELECT * FROM  clientes WHERE Categoria_de_renta = "Empleado"'

# %%
empleados  = pd.read_sql(sql = text(query), con = engine.connect())  ## Executing the query in the engine
empleados
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008815    46    Nivel superior            Casado               2
# 4          5112956    46    Nivel superior            Casado               2
# ...            ...   ...               ...               ...             ...
# 226054     6837905    43  Nivel intermedio            Casado               3
# 226055     6837906    43  Nivel intermedio            Casado               3
# 226056     6839936    34  Nivel intermedio            Casado               3
# 226057     6840222    43  Nivel intermedio           Soltero               1
# 226058     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %%
type(empleados)
# Out:
# pandas.core.frame.DataFrame

# %%
empleados.to_sql('empleados', con = engine.connect(), index=False )
# Out:
# 226059

# %% [markdown]
# ## **Reading with Pandas**

# %%
pd.read_sql_table('empleados', con = engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008815    46    Nivel superior            Casado               2
# 4          5112956    46    Nivel superior            Casado               2
# ...            ...   ...               ...               ...             ...
# 226054     6837905    43  Nivel intermedio            Casado               3
# 226055     6837906    43  Nivel intermedio            Casado               3
# 226056     6839936    34  Nivel intermedio            Casado               3
# 226057     6840222    43  Nivel intermedio           Soltero               1
# 226058     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %%
pd.read_sql_table('empleados', con = engine.connect(), columns = ['ID_Cliente', 'Grado_estudio', 'Rendimiento_anual'])
# Out:
#         ID_Cliente     Grado_estudio  Rendimiento_anual
# 0          5008804    Nivel superior           427500.0
# 1          5008805    Nivel superior           427500.0
# 2          5008806  Nivel intermedio           112500.0
# 3          5008815    Nivel superior           270000.0
# 4          5112956    Nivel superior           270000.0
# ...            ...               ...                ...
# 226054     6837905  Nivel intermedio           355050.0
# 226055     6837906  Nivel intermedio           355050.0
# 226056     6839936  Nivel intermedio           135000.0
# 226057     6840222  Nivel intermedio           103500.0
# 226058     6842885  Nivel intermedio           121500.0
#
# [226059 rows x 3 columns]

# %% [markdown]
# ## **Updating BD**

# %%
query = 'SELECT * FROM clientes'

pd.read_sql(sql=text(query), con=engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008808    52  Nivel intermedio           Soltero               1
# 4          5008809    52  Nivel intermedio           Soltero               1
# ...            ...   ...               ...               ...             ...
# 438458     6840104    62  Nivel intermedio        Divorciado               1
# 438459     6840222    43  Nivel intermedio           Soltero               1
# 438460     6841878    22    Nivel superior           Soltero               1
# 438461     6842765    59  Nivel intermedio            Casado               2
# 438462     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %% [markdown]
# ### **Deleting records**

# %%
from sqlalchemy.exc import SQLAlchemyError

# %%
query = 'DELETE FROM clientes where ID_Cliente=5008804'
try:
  r_set = engine.connect().execute(text(query))
except SQLAlchemyError as e:
  print(e)
else:
  print('#Registros Borrados: ', r_set.rowcount)
# Out:
# #Registros Borrados:  1

# %%
pd.read_sql_table('clientes', con=engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008805    32    Nivel superior  Relación-estable               2
# 1          5008806    58  Nivel intermedio            Casado               2
# 2          5008808    52  Nivel intermedio           Soltero               1
# 3          5008809    52  Nivel intermedio           Soltero               1
# 4          5008810    52  Nivel intermedio           Soltero               1
# ...            ...   ...               ...               ...             ...
# 438457     6840104    62  Nivel intermedio        Divorciado               1
# 438458     6840222    43  Nivel intermedio           Soltero               1
# 438459     6841878    22    Nivel superior           Soltero               1
# 438460     6842765    59  Nivel intermedio            Casado               2
# 438461     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %% [markdown]
# ### **Updating records**

# %%
query = 'UPDATE clientes SET Grado_estudio="Nievel superior" where ID_Cliente=5008808'
try:
  r_set = engine.connect().execute(text(query))
except SQLAlchemyError as e:
  print(e)
else:
  print('#Registros actualizados: ', r_set.rowcount)
# Out:
# #Registros actualizados:  1

# %%
pd.read_sql_table('clientes', con=engine.connect()).head()
# Out:
#    ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0     5008805    32    Nivel superior  Relación-estable               2
# 1     5008806    58  Nivel intermedio            Casado               2
# 2     5008808    52   Nievel superior           Soltero               1
# 3     5008809    52  Nivel intermedio           Soltero               1
# 4     5008810    52  Nivel intermedio           Soltero               1
#
#   Categoria_de_renta  Ocupacion  Años_empleado  Rendimiento_anual  \
# 0           Empleado       Otro             12           427500.0
# 1           Empleado  Seguridad              3           112500.0
# 2   Business Partner     Ventas              8           270000.0
# 3   Business Partner     Ventas              8           270000.0
# 4   Business Partner     Ventas              8           270000.0
#
#    Tiene_carro                  Vivienda
# 0            1    Departamento alquilado
# 1            1  Casa/Departamento propio
# ...

# %% [markdown]
# ## **Desafío: manipulando una base de datos**

# %% [markdown]
# Usted es responsable de crear una base de datos local de clientes para una institución financiera. Disponemos del [archivo CSV](https://github.com/alura-es-cursos/1980-Pandas_IO/raw/clientes_banco/clientes_banco.csv.zip) con los datos de los clientes.
#
# Tu misión es:
#
# 1. Crear la base de datos local con la biblioteca SQLAlchemy.
# 2. Escribir los datos del archivo CSV en esta base de datos local.
# 3. Realizar tres actualizaciones en la base de datos:
#   * Actualizar el registro del cliente ID 6840104 cuyo rendimiento anual cambió a 300000.
#   * Eliminar el registro de cliente ID 5008809, ya que esta persona ya no tiene cuenta en la institución financiera.
#   * Crear un nuevo registro de cliente siguiendo las especificaciones a continuación:
#     * ID_cliente: 6850985
#     * Edad: 33
#     * Grado_estudio: Doctorado
#     * Estado_civil: Soltero
#     * Tamaño_familia: 1
#     * Categoria_de_renta: Empleado
#     * Ocupacion: TI
#     * Años_empleado: 2
#     * Rendimiento_anual: 290000
#     * Tiene_carro: 0
#     * Vivienda: Casa/Departamento propio

# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine,MetaData, Table, inspect, text
from sqlalchemy.exc import SQLAlchemyError

## importing CSV
data_clientes = pd.read_csv('/content/drive/MyDrive/ONE/05_Pandas_IO/clientes_banco_challenge.csv')

## mounting engine
engine = create_engine('sqlite:///:memory:')

### exporting to SQL
data_clientes.to_sql('clientes', engine, index=False)

## checking database status
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['clientes']

# %%
query = 'SELECT * FROM clientes'
pd.read_sql(sql=text(query), con=engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008808    52  Nivel intermedio           Soltero               1
# 4          5008809    52  Nivel intermedio           Soltero               1
# ...            ...   ...               ...               ...             ...
# 438458     6840104    62  Nivel intermedio        Divorciado               1
# 438459     6840222    43  Nivel intermedio           Soltero               1
# 438460     6841878    22    Nivel superior           Soltero               1
# 438461     6842765    59  Nivel intermedio            Casado               2
# 438462     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %%
## Updating
query = 'UPDATE clientes SET Rendimiento_anual=300000 where ID_Cliente=6840104'
try:
  r_set = engine.connect().execute(text(query))
except SQLAlchemyError as e:
  print(e)
else:
  print('#Registros actualizados: ', r_set.rowcount)

query = 'SELECT * FROM clientes where ID_Cliente=6840104'
pd.read_sql(sql=text(query), con=engine.connect())
# Out:
# #Registros actualizados:  1
#    ID_Cliente  Edad     Grado_estudio Estado_civil  Tamaño_familia  \
# 0     6840104    62  Nivel intermedio   Divorciado               1
#
#   Categoria_de_renta Ocupacion  Años_empleado  Rendimiento_anual  Tiene_carro  \
# 0        Pensionista      Otro              0           300000.0            0
#
#                    Vivienda
# 0  Casa/Departamento propio

# %%
## Deleting
query = 'DELETE FROM clientes where ID_Cliente=5008809'
try:
  r_set = engine.connect().execute(text(query))
except SQLAlchemyError as e:
  print(e)
else:
  print('#Registros Borrados: ', r_set.rowcount)
query = 'SELECT * FROM clientes'
pd.read_sql(sql=text(query), con=engine.connect()).head()
# Out:
# #Registros Borrados:  1
#    ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0     5008804    32    Nivel superior  Relación-estable               2
# 1     5008805    32    Nivel superior  Relación-estable               2
# 2     5008806    58  Nivel intermedio            Casado               2
# 3     5008808    52  Nivel intermedio           Soltero               1
# 4     5008810    52  Nivel intermedio           Soltero               1
#
#   Categoria_de_renta  Ocupacion  Años_empleado  Rendimiento_anual  \
# 0           Empleado       Otro             12           427500.0
# 1           Empleado       Otro             12           427500.0
# 2           Empleado  Seguridad              3           112500.0
# 3   Business Partner     Ventas              8           270000.0
# 4   Business Partner     Ventas              8           270000.0
#
#    Tiene_carro                  Vivienda
# 0            1    Departamento alquilado
# ...

# %%
## Adding
query = 'INSERT INTO clientes (ID_Cliente, Edad, Grado_estudio, Estado_civil, ' \
        'Tamaño_familia, Categoria_de_renta, Ocupacion, Años_empleado, ' \
        'Rendimiento_anual, Tiene_carro, Vivienda) ' \
        'VALUES (6850985, 33, "Doctorado", "Soltero", 1, "Empleado", "TI", ' \
        '2, 290000, 0, "Casa/Departamento propio")'
try:
  r_set = engine.connect().execute(text(query))
except SQLAlchemyError as e:
  print(e)
else:
  print('#Registros actualizados: ', r_set.rowcount)

query = 'SELECT * FROM clientes where ID_Cliente=6850985'
pd.read_sql(sql=text(query), con=engine.connect())
# Out:
# #Registros actualizados:  1
#    ID_Cliente  Edad Grado_estudio Estado_civil  Tamaño_familia  \
# 0     6850985    33     Doctorado      Soltero               1
#
#   Categoria_de_renta Ocupacion  Años_empleado  Rendimiento_anual  Tiene_carro  \
# 0           Empleado        TI              2           290000.0            0
#
#                    Vivienda
# 0  Casa/Departamento propio

# %%
pd.read_sql_table('clientes', con=engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008808    52  Nivel intermedio           Soltero               1
# 4          5008810    52  Nivel intermedio           Soltero               1
# ...            ...   ...               ...               ...             ...
# 438458     6840222    43  Nivel intermedio           Soltero               1
# 438459     6841878    22    Nivel superior           Soltero               1
# 438460     6842765    59  Nivel intermedio            Casado               2
# 438461     6842885    51  Nivel intermedio            Casado               2
# 438462     6850985    33         Doctorado           Soltero               1
#
# ...
